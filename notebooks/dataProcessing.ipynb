# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_nodes_1 = pd.read_csv('../data/gauss1_samples(1).csv')
df_nodes_1.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  128.000000  128.000000  128.000000  128.000000  128.000000  128.000000
# mean     0.100000    0.100000    0.100000    0.100000  100.000000  100.000000
# std      0.010039    0.010039    0.010039    0.010039   10.039293   10.039293
# min      0.090000    0.090000    0.090000    0.090000   90.000000   90.000000
# 25%      0.090000    0.090000    0.090000    0.090000   90.000000   90.000000
# 50%      0.100000    0.100000    0.100000    0.100000  100.000000  100.000000
# 75%      0.110000    0.110000    0.110000    0.110000  110.000000  110.000000
# max      0.110000    0.110000    0.110000    0.110000  110.000000  110.000000
#
#                 6
# count  128.000000
# mean   100.000000
# std     10.039293
# min     90.000000
# 25%     90.000000
# 50%    100.000000
# 75%    110.000000
# max    110.000000

# %%
df_nodes_2 = pd.read_csv('../data/gauss2_samples(1).csv')
df_nodes_2.describe()
# Out:
#                  0            1            2            3            4  \
# count  2187.000000  2187.000000  2187.000000  2187.000000  2187.000000
# mean      0.100000     0.100000     0.100000     0.100000   100.000000
# std       0.014145     0.014145     0.014145     0.014145    14.145370
# min       0.082679     0.082679     0.082679     0.082679    82.679492
# 25%       0.082679     0.082679     0.082679     0.082679    82.679492
# 50%       0.100000     0.100000     0.100000     0.100000   100.000000
# 75%       0.117321     0.117321     0.117321     0.117321   117.320508
# max       0.117321     0.117321     0.117321     0.117321   117.320508
#
#                  5            6
# count  2187.000000  2187.000000
# mean    100.000000   100.000000
# std      14.145370    14.145370
# min      82.679492    82.679492
# 25%      82.679492    82.679492
# 50%     100.000000   100.000000
# 75%     117.320508   117.320508
# max     117.320508   117.320508

# %%
df_mlab_1 = pd.read_csv('../data/displace_23.csv')
df_mlab_1.describe()
# Out:
#           drive_1     drive_2     drive_3     drive_4       T_TOP       T_MID  \
# count  128.000000  128.000000  128.000000  128.000000  128.000000  128.000000
# mean     0.100000    0.100000    0.100000    0.100000  100.000000  100.000000
# std      0.010039    0.010039    0.010039    0.010039   10.039293   10.039293
# min      0.090000    0.090000    0.090000    0.090000   90.000000   90.000000
# 25%      0.090000    0.090000    0.090000    0.090000   90.000000   90.000000
# 50%      0.100000    0.100000    0.100000    0.100000  100.000000  100.000000
# 75%      0.110000    0.110000    0.110000    0.110000  110.000000  110.000000
# max      0.110000    0.110000    0.110000    0.110000  110.000000  110.000000
#
#             T_END         Z23
# count  128.000000  128.000000
# mean   100.000000   52.054545
# std     10.039293    3.679487
# min     90.000000   43.618571
# 25%     90.000000   48.723230
# 50%    100.000000   52.130196
# 75%    110.000000   54.758515
# ...

# %%
df_mlab_2 = pd.read_csv('../data/displace_23_2.csv')
df_mlab_2.describe()
# Out:
#            drive_1      drive_2      drive_3      drive_4        T_TOP  \
# count  2187.000000  2187.000000  2187.000000  2187.000000  2187.000000
# mean      0.100000     0.100000     0.100000     0.100000   100.000000
# std       0.014145     0.014145     0.014145     0.014145    14.145370
# min       0.082679     0.082679     0.082679     0.082679    82.679492
# 25%       0.082679     0.082679     0.082679     0.082679    82.679492
# 50%       0.100000     0.100000     0.100000     0.100000   100.000000
# 75%       0.117321     0.117321     0.117321     0.117321   117.320508
# max       0.117321     0.117321     0.117321     0.117321   117.320508
#
#              T_MID        T_END          Z23
# count  2187.000000  2187.000000  2171.000000
# mean    100.000000   100.000000    45.974606
# std      14.145370    14.145370    25.444324
# min      82.679492    82.679492  -171.087531
# 25%      82.679492    82.679492    47.934976
# 50%     100.000000   100.000000    51.140817
# ...

# %% [markdown]
# ## 1. A better column naming
# Comparing to the matlab output file, the column names in the input csv files make no sense. It should be changed to represent the relevant  independent variables.

# %%
df_mlab_2['Z23'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df_mlab_1['Z23'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2. How the two different histogram compares.

# %%
df_nodes_1['1'].value_counts()
# Out:
# 0.09    64
# 0.11    64
# Name: 1, dtype: int64

# %%
df_nodes_2['5'].value_counts()
# Out:
# 82.679492     729
# 117.320508    729
# 100.000000    729
# Name: 5, dtype: int64

# %%
3**7
# Out:
# 2187

# %%
5**7
# Out:
# 78125

# %% [markdown]
# ## 3. How much time for data preparation of the 5th order pce?

# %% [markdown]
# ## 4. input variance range selection

# %% [markdown]
# ## 5. GSA
